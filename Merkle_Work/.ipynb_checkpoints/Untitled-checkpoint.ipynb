# %%
import pandas as pd
adv_stats = pd.read_csv("../data/adv_team_2018.csv")
adv_stats.head()
# Out:
#              Team     MP    FG   FGA    FG.   X2P  X2PA   X2P.   X3P  X3PA  \
# 0        canisius  200.0  25.0  52.0  0.481  17.0  31.0  0.548   8.0  21.0
# 1         buffalo  200.0  30.0  73.0  0.411  23.0  49.0  0.469   7.0  24.0
# 2    pennsylvania  200.0  26.0  72.0  0.361  17.0  33.0  0.515   9.0  39.0
# 3       fairfield  200.0  28.0  56.0  0.500  24.0  39.0  0.615   4.0  17.0
# 4  illinois-state  200.0  33.0  65.0  0.508  19.0  36.0  0.528  14.0  29.0
#
#        ...         TOV_pct  OPP.TOV_pct   FT_rate  OPP.FT_rate     X3PAR  \
# 0      ...        0.229709     0.127932  0.326923     0.178082  0.403846
# 1      ...        0.127932     0.229709  0.178082     0.326923  0.328767
# 2      ...        0.100716     0.193798  0.152778     0.357143  0.541667
# 3      ...        0.193798     0.100716  0.357143     0.152778  0.303571
# 4      ...        0.132466     0.119202  0.107692     0.415385  0.446154
#
#    Opp.3PAR    ast_to  Opp.ast_to  fouls_min  Opp.fouls_min
# 0  0.328767  0.722222    0.750000      0.100          0.110
# 1  0.403846  0.750000    0.722222      0.110          0.100
# 2  0.303571  1.555556    0.812500      0.105          0.110
# 3  0.541667  0.812500    1.555556      0.110          0.105
# 4  0.353846  2.181818    1.454545      0.130          0.080
#
# [5 rows x 65 columns]

# %%
adv_stats.fillna(0,inplace=True)
adv_stats = adv_stats.drop(["Team","Opp.Team","gameid","PTS","Opp.PTS","MP","X2P","X2PA","X3P","X3PA",
                           "Opp.2P","Opp.2PA","Opp.3P","Opp.3PA","FG","FGA","Opp.FG","Opp.FGA",
                           "FT","FTA","Opp.FT","Opp.FTA","FT.","Opp.FT.",
                            "FG.","Opp.FG.","X2P.","X3P.","Opp.2P.","Opp.3P.",
                           "PF","Opp.PF","Opp.ORB","ORB","Opp.TRB","TRB",
                           "AST","TOV","Opp.AST","Opp.TOV"],axis=1)
adv_stats.head()
# Out:
#     DRB  STL  BLK  Opp.DRB  Opp.STL  Opp.BLK  Win.  possessions  \
# 0  23.0  4.0  6.0     19.0      8.0      2.0     0       73.025
# 1  19.0  8.0  2.0     23.0      4.0      6.0     1       77.500
# 2  23.0  6.0  3.0     37.0      5.0      5.0     0       83.025
# 3  37.0  5.0  5.0     23.0      6.0      3.0     1       76.400
# 4  19.0  3.0  5.0     30.0      9.0      5.0     0       80.600
#
#    Opp.possessions       efg      ...         TOV_pct  OPP.TOV_pct   FT_rate  \
# 0           77.500  0.557692      ...        0.229709     0.127932  0.326923
# 1           73.025  0.458904      ...        0.127932     0.229709  0.178082
# 2           76.400  0.423611      ...        0.100716     0.193798  0.152778
# 3           83.025  0.535714      ...        0.193798     0.100716  0.357143
# 4           80.575  0.615385      ...        0.132466     0.119202  0.107692
#
#    OPP.FT_rate     X3PAR  Opp.3PAR    ast_to  Opp.ast_to  fouls_min  \
# 0     0.178082  0.403846  0.328767  0.722222    0.750000      0.100
# 1     0.326923  0.328767  0.403846  0.750000    0.722222      0.110
# 2     0.357143  0.541667  0.303571  1.555556    0.812500      0.105
# 3     0.152778  0.303571  0.541667  0.812500    1.555556      0.110
# 4     0.415385  0.446154  0.353846  2.181818    1.454545      0.130
#
#    Opp.fouls_min
# 0          0.110
# 1          0.100
# 2          0.110
# 3          0.105
# 4          0.080
#
# [5 rows x 25 columns]

# %%
wins = adv_stats[["Win."]]
adv_stats = adv_stats.drop(["Win."],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(adv_stats,wins,test_size = 0.30, random_state=22)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import ensemble

# %%
extc = ExtraTreesClassifier(n_estimators=1000,criterion='gini',min_samples_split= 5,
                            min_samples_leaf= 5)

# %%
extc.fit(X_train,y_train)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np
importances = extc.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. %s (%.3f) (%.3f)" % (f + 1, X_train.columns[indices[f]], importances[indices[f]]*100,
                                    np.sum(importances[indices[0:f+1]]*100)))

# %%
y_pred = extc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
